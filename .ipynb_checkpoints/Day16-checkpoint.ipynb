# %% [markdown]
# # Linear Regression using Scikit-learn

# %% [markdown]
# Ek supervised ML algorithm jo numerical (continuous) value predict karta hai based on input.

# %% [markdown]
# > House price prediction
#
# > Salary prediction
#
# > Sales forecasting

# %% [markdown]
# 𝑦 = 𝑚𝑥 + 𝑐

# %%
import pandas as pd

# Sample data for salary prediction
df = pd.read_csv("Data Sample Storage/salary_data.csv")
df.head()
# Out:
#    YearsExperience    Salary
# 0              8.1  41370.47
# 1             19.1  92509.93
# 2             14.9  75417.61
# 3             12.4  42124.31
# 4              4.0  17803.28

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X = df.drop("Salary", axis=1)
y = df['Salary']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from PIL import Image 
from IPython.display import display
display(Image.open(r"C:\Users\renuk\OneDrive\Pictures\Screenshots\Screenshot 2025-07-08 033316.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=565x298>

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
# Predict
y_pred = model.predict(X_test)
# Compare
from sklearn.metrics import mean_squared_error, r2_score
print("R2 Score:", r2_score(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.9232241399389358
# MSE: 73868068.8390438

# %%
import matplotlib.pyplot as plt

plt.scatter(X_test, y_test, color='red')
plt.plot(X_test, y_pred, color='blue')
plt.title("Actual vs Predicted Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
import numpy as np
def predict_salary(experience):
    years = np.array([[experience]])
    prediction = model.predict(years)[0]
    return round(prediction, 2)

example_prediction = predict_salary(10)
example_prediction
# Out:
# C:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 49656.14

# %% [markdown]
# # ✅ Homework:
# # Try same model with your own CSV (e.g., house price, marks vs study hours)
#
# # Plot both: scatter and regression line
