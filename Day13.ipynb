# %%
# 🟢 1. Installing Jupyter Notebook (10 mins)
# ✅ Steps:
# window -> type "System Environment variable" -> click on environment variable
# -> path click-> new click-> add the python address

# create a Folder Name Jupyter Notebook By Nexyug Tech
# inside the folder Open terminal / command prompt

# Install using pip:
# >>pip install notebook
# Launch it:

# >>jupyter notebook

# Explain:
# It runs in the browser
# Used for writing code + notes (Markdown)
# Very popular in data science

# %%
# 🔵 2. What is Machine Learning? (10 mins)
# Definition: Machine Learning is the ability of a system to learn from data without being explicitly programmed.

# Give simple real-world examples:
# YouTube recommendation
# Face unlock
# Spam filter

# Explain key idea:
# 👉 Data → Model → Prediction

# %%
# 🟠 3. Types of Machine Learning (10 mins)
# Type	                    Description	                              Example
# Supervised Learning	 -> Learn from labeled data	              -> Email spam detection
# Unsupervised Learning  -> Learn from patterns in unlabeled data -> Customer segmentation
# Reinforcement Learning -> Learn by rewards & punishments        -> Self-driving cars, Games

# %%
from PIL import Image 
from IPython.display import display
display(Image.open(r"C:\Users\renuk\OneDrive\Pictures\Screenshots\Screenshot 2025-06-28 131311.png").resize((600, 400)))
# Out:
# <PIL.Image.Image image mode=RGBA size=600x400>

# %%
# 🟣 4. ML Project Lifecycle (10 mins)
# Stages:
# Problem Definition:            >> Define business goals and frame the machine learning challenge.
# Data Collection:               >> Gather relevant and sufficient data for modeling.
# Data Cleaning & Preprocessing: >> Fix issues and format data for consistency.
# Model Selection & Training:    >> Choose the right algorithm and train it on prepared data.
# Evaluation:                    >> Test the model’s performance using metrics like accuracy or F1 score.
# Deployment:                    >> Integrate the model into real systems for practical use.

# Data → Preprocessing → Model Training → Evaluation → Deployment

# %%
display(Image.open(r"C:\Users\renuk\OneDrive\Pictures\Screenshots\Screenshot 2025-07-04 094529.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=921x605>

# %%
# Block Diagram

# %%
display(Image.open(r"C:\Users\renuk\OneDrive\Pictures\Screenshots\Screenshot 2025-07-04 095859.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1063x225>

# %%
# 🟢 5. QuickReview What we Learn Today 

# Installation of Jupyter Notebook 

# Introduction of Machine Learing 

# Type of Machine Learning : 
# Supervised Learing(deal with labeled data), 
# Unsupervised Learing(deal with unlabeled data) &
# Reinforcement Learing(we deal With AI agent)

# Block Diagram

# Lifecycle of Machine Learing 
# Data Collection → Data Preprocessing → Model Training → Evaluation → Deployment
